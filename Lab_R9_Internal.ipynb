# %% [markdown]
# # Bounding box detection - Racoon data
#
#
# ## Data files
# - images_racoon.rar: contain images of racoons
# - train_labels.cv: contains coordinates for bounding box for every image

# %% [markdown]
# ### Import the necessary libraries

# %%
# %tensorflow_version 2.x
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.1.0

# %%
# IMPORT LIBRARIES AND PACKAGES
import tensorflow as tf
import csv
import numpy as np
from PIL import Image
import pandas as pd

from tensorflow.keras import Model
from tensorflow.keras.applications.mobilenet import MobileNet, preprocess_input
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau, Callback
from tensorflow.keras.layers import Conv2D, Reshape
from tensorflow.keras.utils import Sequence
from tensorflow.keras.backend import epsilon

# %% [markdown]
# ### Change directory

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
os.chdir('/content/drive/My Drive/GreatLearning/myprojects/Residency9/')

# %% [markdown]
# ### Load the training data from train.csv file

# %%
DATASET_FOLDER = "/content/drive/My Drive/GreatLearning/myprojects/Residency9/"

# %%
TRAIN_CSV = DATASET_FOLDER+"train_labels.csv"

# %%
x_train = pd.read_csv(TRAIN_CSV)

# %%
# !pip install rarfile
# Out:
# Requirement already satisfied: rarfile in /usr/local/lib/python3.6/dist-packages (3.1)

# %%
# !pip install pyunpack
# Out:
# Requirement already satisfied: pyunpack in /usr/local/lib/python3.6/dist-packages (0.1.2)
# Requirement already satisfied: easyprocess in /usr/local/lib/python3.6/dist-packages (from pyunpack) (0.2.10)

# %%
# !pip install patool
# Out:
# Requirement already satisfied: patool in /usr/local/lib/python3.6/dist-packages (1.12)

# %% [markdown]
# ### Print the shape of the train dataset

# %%
x_train.shape
# Out:
# (173, 8)

# %% [markdown]
# Extracting images from rar files

# %%
# !ls
# Out:
# '1. Sentiment_Analysis_Embedding_RNN_LSTM.ipynb'
# '1. Seq2Seq LSTM Model Language Translation.ipynb'
#  Bounding_Box_Class_version.ipynb
#  daily-minimum-temperatures-in-me.csv
#  Day_2-20200301T033713Z-001.zip
#  hin-eng.zip
#  images_racoon.rar
#  international-airline-passengers.csv
#  labeledTrainData.tsv.zip
#  news_articles.csv
#  product_reviews_dataset.csv
#  R9_Internal_Lab_practice.ipynb
#  R9_Internal_Lab_Questions.ipynb
#  SingleBoundingBoxV1.ipynb
#  Text_generation_LSTM_word_level.ipynb
#  Text_to_Numbers_Embeddings_visualisation.ipynb
#  train.csv
#  train_labels.csv
#  updated_train_labels.csv
#  validation.csv
#  word2vec_data.tsv.zip
#  word2vec_gensim.ipynb

# %%
from rarfile import RarFile

with RarFile('images_racoon.rar') as file:
    file.extractall()

# %%
# !pwd
# Out:
# /content/drive/My Drive/GreatLearning/myprojects/Residency9

# %%
# !ls
# Out:
# '1. Sentiment_Analysis_Embedding_RNN_LSTM.ipynb'
# '1. Seq2Seq LSTM Model Language Translation.ipynb'
#  Bounding_Box_Class_version.ipynb
#  daily-minimum-temperatures-in-me.csv
#  Day_2-20200301T033713Z-001.zip
#  hin-eng.zip
#  images
#  images_racoon.rar
#  international-airline-passengers.csv
#  labeledTrainData.tsv.zip
#  news_articles.csv
#  product_reviews_dataset.csv
#  R9_Internal_Lab_practice.ipynb
#  R9_Internal_Lab_Questions.ipynb
#  SingleBoundingBoxV1.ipynb
#  Text_generation_LSTM_word_level.ipynb
#  Text_to_Numbers_Embeddings_visualisation.ipynb
#  train.csv
#  train_labels.csv
#  updated_train_labels.csv
#  validation.csv
#  word2vec_data.tsv.zip
#  word2vec_gensim.ipynb

# %% [markdown]
# ### Declare a variable IMAGE_SIZE = 128 as we will be using MobileNet which will be taking Input shape as 128 * 128

# %%
IMAGE_SIZE = 128 # MobileNet takes images of size 128*128*3

# %% [markdown]
# ### With the help of csv.reader write a for loop which can load the train.csv file and store the path, width, height, x0,y0,x1,y1 in induvidual variables. <br>
# 1. Create a list variable known as 'path' which has all the path for all the training images
# 2. Create an array 'coords' which has the resized coordinates of the bounding box for the training images
#
# <u>Note:</u> All the training images should be downsampled to 128 * 128 as it is the input shape of MobileNet (which we will be using for Object detection). Hence the corresponding coordinates of the bounding boxes should be changed to match the image dimension of 128 * 128

# %%
OUTPUT_FOLDER = DATASET_FOLDER + 'images'

# %%
OUTPUT_FOLDER
# Out:
# '/content/drive/My Drive/GreatLearning/myprojects/Residency9/images'

# %%
images_rar_path = DATASET_FOLDER + 'images_racoon.rar'

# %%
images_rar_path
# Out:
# '/content/drive/My Drive/GreatLearning/myprojects/Residency9/images_racoon.rar'

# %%
#Another way to unrar/unzip files
#from pyunpack import Archive

#Archive(images_rar_path).extractall(OUTPUT_FOLDER)

# %%
TRAIN_CSV
# Out:
# '/content/drive/My Drive/GreatLearning/myprojects/Residency9/train_labels.csv'

# %%
# !pwd
# Out:
# /content/drive/My Drive/GreatLearning/myprojects/Residency9

# %%
OUTPUT_FOLDER
# Out:
# '/content/drive/My Drive/GreatLearning/myprojects/Residency9/images'

# %%
with open(TRAIN_CSV,'r') as f:
    with open(DATASET_FOLDER+"updated_train_labels.csv",'w') as f1:
        next(f) # skip header line
        for line in f:
            f1.write(line)
            
TRAIN_CSV_UPDATED = "updated_train_labels.csv"

# %%
import csv
with open(DATASET_FOLDER + TRAIN_CSV_UPDATED, 'r') as csvfile:
    paths = []
    coords = np.zeros((sum(1 for line in csvfile), 4))
    reader = csv.reader(csvfile, delimiter=',')
    csvfile.seek(0)
    for col, row in enumerate(reader):
               
        for i, r in enumerate(row[1:8]):
          if (i !=2 ):
            row[i+1] = int(r)
              
        path, image_width, image_height, class1, x0, y0, x1, y1 = row  
        coords[col, 0] = x0 * IMAGE_SIZE / image_width # Normalize bounding box by image size
        coords[col, 1] = y0 * IMAGE_SIZE / image_height # Normalize bounding box by image size
        coords[col, 2] = x1 * IMAGE_SIZE / image_width # Normalize bounding box by image size
        coords[col, 3] = y1 * IMAGE_SIZE / image_height
        paths.append(path)

# %%
paths
# Out:
# ['raccoon-17.jpg',
#  'raccoon-11.jpg',
#  'raccoon-63.jpg',
#  'raccoon-63.jpg',
#  'raccoon-60.jpg',
#  'raccoon-69.jpg',
#  'raccoon-180.jpg',
#  'raccoon-200.jpg',
#  'raccoon-141.jpg',
#  'raccoon-19.jpg',
#  'raccoon-84.jpg',
#  'raccoon-124.jpg',
#  'raccoon-182.jpg',
#  'raccoon-111.jpg',
#  'raccoon-91.jpg',
#  'raccoon-79.jpg',
#  'raccoon-93.jpg',
#  'raccoon-20.jpg',
#  'raccoon-42.jpg',
#  'raccoon-139.jpg',
#  'raccoon-58.jpg',
#  'raccoon-71.jpg',
#  'raccoon-183.jpg',
#  'raccoon-1.jpg',
#  'raccoon-169.jpg',
#  'raccoon-82.jpg',
#  'raccoon-4.jpg',
#  'raccoon-101.jpg',
#  'raccoon-10.jpg',
#  'raccoon-166.jpg',
#  'raccoon-184.jpg',
#  'raccoon-38.jpg',
#  'raccoon-120.jpg',
#  'raccoon-142.jpg',
#  'raccoon-149.jpg',
#  'raccoon-51.jpg',
#  'raccoon-43.jpg',
#  'raccoon-123.jpg',
#  'raccoon-66.jpg',
#  'raccoon-9.jpg',
#  'raccoon-178.jpg',
#  'raccoon-47.jpg',
#  'raccoon-167.jpg',
#  'raccoon-54.jpg',
#  'raccoon-77.jpg',
#  'raccoon-155.jpg',
#  'raccoon-89.jpg',
#  'raccoon-153.jpg',
#  'raccoon-179.jpg',
#  'raccoon-115.jpg',
#  'raccoon-64.jpg',
#  'raccoon-56.jpg',
#  'raccoon-44.jpg',
#  'raccoon-39.jpg',
#  'raccoon-26.jpg',
#  'raccoon-162.jpg',
#  'raccoon-170.jpg',
#  'raccoon-187.jpg',
#  'raccoon-131.jpg',
#  'raccoon-174.jpg',
#  'raccoon-92.jpg',
#  'raccoon-193.jpg',
#  'raccoon-138.jpg',
#  'raccoon-157.jpg',
#  'raccoon-108.jpg',
#  'raccoon-116.jpg',
#  'raccoon-117.jpg',
#  'raccoon-117.jpg',
#  'raccoon-12.jpg',
#  'raccoon-12.jpg',
#  'raccoon-16.jpg',
#  'raccoon-90.jpg',
#  'raccoon-160.jpg',
#  'raccoon-75.jpg',
#  'raccoon-199.jpg',
#  'raccoon-97.jpg',
#  'raccoon-188.jpg',
#  'raccoon-21.jpg',
#  'raccoon-35.jpg',
#  'raccoon-85.jpg',
#  'raccoon-49.jpg',
#  'raccoon-86.jpg',
#  'raccoon-34.jpg',
#  'raccoon-196.jpg',
#  'raccoon-96.jpg',
#  'raccoon-3.jpg',
#  'raccoon-2.jpg',
#  'raccoon-52.jpg',
#  'raccoon-81.jpg',
#  'raccoon-112.jpg',
#  'raccoon-18.jpg',
#  'raccoon-94.jpg',
#  'raccoon-98.jpg',
#  'raccoon-83.jpg',
#  'raccoon-36.jpg',
#  'raccoon-24.jpg',
#  'raccoon-24.jpg',
#  'raccoon-195.jpg',
#  'raccoon-55.jpg',
#  'raccoon-55.jpg',
#  'raccoon-175.jpg',
#  'raccoon-163.jpg',
#  'raccoon-48.jpg',
#  'raccoon-70.jpg',
#  'raccoon-119.jpg',
#  'raccoon-119.jpg',
#  'raccoon-119.jpg',
#  'raccoon-88.jpg',
#  'raccoon-61.jpg',
#  'raccoon-61.jpg',
#  'raccoon-121.jpg',
#  'raccoon-74.jpg',
#  'raccoon-133.jpg',
#  'raccoon-177.jpg',
#  'raccoon-177.jpg',
#  'raccoon-159.jpg',
#  'raccoon-53.jpg',
#  'raccoon-132.jpg',
#  'raccoon-198.jpg',
#  'raccoon-198.jpg',
#  'raccoon-103.jpg',
#  'raccoon-46.jpg',
#  'raccoon-50.jpg',
#  'raccoon-37.jpg',
#  'raccoon-161.jpg',
#  'raccoon-194.jpg',
#  'raccoon-32.jpg',
#  'raccoon-15.jpg',
#  'raccoon-147.jpg',
#  'raccoon-151.jpg',
#  'raccoon-80.jpg',
#  'raccoon-6.jpg',
#  'raccoon-154.jpg',
#  'raccoon-135.jpg',
#  'raccoon-118.jpg',
#  'raccoon-150.jpg',
#  'raccoon-102.jpg',
#  'raccoon-130.jpg',
#  'raccoon-130.jpg',
#  'raccoon-7.jpg',
#  'raccoon-107.jpg',
#  'raccoon-173.jpg',
#  'raccoon-165.jpg',
#  'raccoon-25.jpg',
#  'raccoon-67.jpg',
#  'raccoon-13.jpg',
#  'raccoon-191.jpg',
#  'raccoon-45.jpg',
#  'raccoon-31.jpg',
#  'raccoon-31.jpg',
#  'raccoon-172.jpg',
#  'raccoon-100.jpg',
#  'raccoon-148.jpg',
#  'raccoon-148.jpg',
#  'raccoon-23.jpg',
#  'raccoon-30.jpg',
#  'raccoon-33.jpg',
#  'raccoon-136.jpg',
#  'raccoon-114.jpg',
#  'raccoon-76.jpg',
#  'raccoon-104.jpg',
#  'raccoon-109.jpg',
#  'raccoon-87.jpg',
#  'raccoon-113.jpg',
#  'raccoon-78.jpg',
#  'raccoon-65.jpg',
#  'raccoon-122.jpg',
#  'raccoon-73.jpg',
#  'raccoon-137.jpg',
#  'raccoon-171.jpg',
#  'raccoon-190.jpg',
#  'raccoon-22.jpg',
#  'raccoon-152.jpg']

# %% [markdown]
# ### Write a for loop which can load all the training images into a variable 'batch_images' using the paths from the 'paths' variable
# <u>Note:</u> Convert the image to RGB scale as the MobileNet accepts 3 channels as inputs

# %%
len(paths)
# Out:
# 173

# %%
OUTPUT_FOLDER
# Out:
# '/content/drive/My Drive/GreatLearning/myprojects/Residency9/images'

# %%
batch_images = np.zeros((len(paths), IMAGE_SIZE, IMAGE_SIZE, 3), dtype=np.float32)
for i, f in enumerate(paths):
    img = Image.open(OUTPUT_FOLDER + '/' + f) # Read image
    img = img.resize((IMAGE_SIZE, IMAGE_SIZE)) # Resize image
    img = img.convert('RGB')
    batch_images[i] = preprocess_input(np.array(img, dtype=np.float32))

# %% [markdown]
# ### Import MobileNet and load MobileNet into a variable named 'model' which takes input shape of 128 * 128 * 3. Freeze all the layers. Add convolution and reshape layers at the end to ensure the output is 4 coordinates

# %%
ALPHA = 1.0 # Width hyper parameter for MobileNet (0.25, 0.5, 0.75, 1.0). Higher width means more accurate but slower

# %%
model = MobileNet(input_shape=(IMAGE_SIZE, IMAGE_SIZE, 3), include_top=False, alpha=ALPHA) # Load pre-trained mobilenet
# Do not include classification (top) layer

# to freeze layers, except the new top layer, of course, which will be added below
for layer in model.layers:
    layer.trainable = False

# Add new top layer which is a conv layer of the same size as the previous layer so that only 4 coords of BBox can be output
x = model.layers[-1].output
x = Conv2D(4, kernel_size=4, name="coords")(x)
# In the line above kernel size should be 3 for img size 96, 4 for img size 128, 5 for img size 160 etc.
x = Reshape((4,))(x) # These are the 4 predicted coordinates of one BBox

model = Model(inputs=model.input, outputs=x)

# %% [markdown]
# ### Define a custom loss function IoU which calculates Intersection Over Union

# %%
gt = coords
def loss(gt,pred):
    intersections = 0
    unions = 0
    diff_width = np.minimum(gt[:,0] + gt[:,2], pred[:,0] + pred[:,2]) - np.maximum(gt[:,0], pred[:,0])
    diff_height = np.minimum(gt[:,1] + gt[:,3], pred[:,1] + pred[:,3]) - np.maximum(gt[:,1], pred[:,1])
    intersection = diff_width * diff_height
    
    # Compute union
    area_gt = gt[:,2] * gt[:,3]
    area_pred = pred[:,2] * pred[:,3]
    union = area_gt + area_pred - intersection

#     Compute intersection and union over multiple boxes
    for j, _ in enumerate(union):
        if union[j] > 0 and intersection[j] > 0 and union[j] >= intersection[j]:
            intersections += intersection[j]
            unions += union[j]

    # Compute IOU. Use epsilon to prevent division by zero
    iou = np.round(intersections / (unions + epsilon()), 4)
    iou = iou.astype(np.float32)
    return iou

def IoU(y_true, y_pred):
    iou = tf.py_function(loss, [y_true, y_pred], tf.float32)
    return iou

# %% [markdown]
# ### Write model.compile function & model.fit function with: <br>
# 1. Optimizer = Adam, Loss = 'mse' and metrics = IoU
# 2. Epochs = 30, batch_size = 32, verbose = 1

# %%
model.compile(optimizer='Adam', loss='mse', metrics=[IoU]) # Regression loss is MSE

# %%
model.fit(batch_images,gt,
            epochs=30,batch_size = 32,
            verbose=1)
# Out:
# Train on 173 samples
# Epoch 1/30
# 173/173 [==============================] - 5s 27ms/sample - loss: 4099.8836 - IoU: 0.0766
# Epoch 2/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 856.7355 - IoU: 0.4098
# Epoch 3/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 424.8395 - IoU: 0.5854
# Epoch 4/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 596.1085 - IoU: 0.5337
# Epoch 5/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 410.1756 - IoU: 0.5976
# Epoch 6/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 213.0830 - IoU: 0.6485
# Epoch 7/30
# 173/173 [==============================] - 4s 22ms/sample - loss: 211.3831 - IoU: 0.6441
# Epoch 8/30
# 173/173 [==============================] - 4s 21ms/sample - loss: 187.5221 - IoU: 0.6772
# Epoch 9/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 149.9152 - IoU: 0.7173
# Epoch 10/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 129.2570 - IoU: 0.7456
# Epoch 11/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 118.6807 - IoU: 0.7536
# Epoch 12/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 110.7053 - IoU: 0.7602
# Epoch 13/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 100.2732 - IoU: 0.7629
# Epoch 14/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 97.6472 - IoU: 0.7684
# Epoch 15/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 87.6158 - IoU: 0.7777
# Epoch 16/30
# 173/173 [==============================] - 4s 20ms/sample - loss: 85.4999 - IoU: 0.7918
# Epoch 17/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 83.2380 - IoU: 0.7736
# Epoch 18/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 81.0876 - IoU: 0.7966
# Epoch 19/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 78.4500 - IoU: 0.7898
# Epoch 20/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 74.3621 - IoU: 0.7972
# Epoch 21/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 71.4426 - IoU: 0.8012
# Epoch 22/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 71.2461 - IoU: 0.7959
# Epoch 23/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 70.4411 - IoU: 0.8064
# Epoch 24/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 69.4584 - IoU: 0.8019
# Epoch 25/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 64.9143 - IoU: 0.7950
# Epoch 26/30
# 173/173 [==============================] - 3s 19ms/sample - loss: 70.4949 - IoU: 0.7989
# Epoch 27/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 65.3814 - IoU: 0.8134
# Epoch 28/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 66.3731 - IoU: 0.8037
# Epoch 29/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 62.4917 - IoU: 0.8084
# Epoch 30/30
# 173/173 [==============================] - 3s 20ms/sample - loss: 63.8523 - IoU: 0.8089

# %% [markdown]
# ### Pick a test image from the given data

# %%
OUTPUT_FOLDER
# Out:
# '/content/drive/My Drive/GreatLearning/myprojects/Residency9/images'

# %%
# Pick a test image, run model, show image, and show predicted bounding box overlaid on the image
import cv2
filename = OUTPUT_FOLDER + '/' + 'raccoon-113.jpg'
unscaled = cv2.imread(filename) # Original image for display

# %% [markdown]
# ### Resize the image to 128 * 128 and preprocess the image for the MobileNet model

# %%
image_height, image_width, _ = unscaled.shape
image = cv2.resize(unscaled, (IMAGE_SIZE, IMAGE_SIZE)) # Rescaled image to run the network
feat_scaled = preprocess_input(np.array(image, dtype=np.float32))

# %% [markdown]
# ### Predict the coordinates of the bounding box for the given test image

# %%
region = model.predict(x=np.array([feat_scaled]))[0] # Predict the BBox

# %% [markdown]
# ### Plot the test image using .imshow and draw a boundary box around the image with the coordinates obtained from the model

# %%
x0 = int(region[0] * image_width / IMAGE_SIZE) # Scale the BBox
y0 = int(region[1] * image_height / IMAGE_SIZE)

x1 = int((region[2]) * image_width / IMAGE_SIZE)
y1 = int((region[3]) * image_height / IMAGE_SIZE)


import matplotlib.pyplot as plt
import matplotlib.patches as patches
from PIL import Image
import numpy as np


# Create figure and axes
fig,ax = plt.subplots(1)

# Display the image
ax.imshow(unscaled)

# Create a Rectangle patch
rect = patches.Rectangle((x0, y0), (x1 - x0), (y1 - y0) , linewidth=2, edgecolor='r', facecolor='none')

# Add the patch to the Axes
ax.add_patch(rect)

plt.show()

# %% [markdown]
# # Time Series Prediction using LSTM

# %% [markdown]
# ### Download Data
# Link: https://datamarket.com/data/set/2324/daily-minimum-temperatures-in-melbourne-australia-1981-1990#!ds=2324&display=line
#
# #### Description
# Daily minimum temperatures in Melbourne, Australia, 1981-1990
#
# Units: Degrees Celcius
#
# #### Steps before loading
# - Rename the column name with temprature values to "Temprature"
# - In the last, there is one extra row in the data, remove it by opening the file and save it again.
# - There are some values in Temprature column which have a "?" before them, they will give error, remove "?" before them and save the file
# - If you don't want to do these steps, just load the data file given by Great Learning.

# %% [markdown]
# #### Mount google drive

# %% [markdown]
# #### Change your present working directory

# %% [markdown]
# ### Load your data file

# %% [markdown]
# #### Plot data

# %% [markdown]
# #### Descibe your dataframe

# %% [markdown]
# #### Check for null values

# %% [markdown]
# #### Drop null values

# %% [markdown]
# #### Get the representation of the distribution of data in the form of histogram

# %% [markdown]
# #### Check the maximum and minimum values

# %% [markdown]
# ### Normalize the data

# %% [markdown]
# #### Check the maximum and minimum values of scaled data

# %% [markdown]
# #### Look into some of the scaled values

# %% [markdown]
# ### Split data into Training and Testing

# %% [markdown]
# #### Print train and test size

# %% [markdown]
# ## Create the sequential data
# Map the temprature at a particular time t to the temprature at time t+n, where n is any number you define.
#
# For example: to map tempratures of consecutive days, use t+1, i.e. loop_back = 1

# %% [markdown]
# #### Define your function to create dataset

# %% [markdown]
# #### Use function to get training and test set

# %% [markdown]
# #### Transform the prepared train and test input data into the expected structure using numpy.reshape()

# %% [markdown]
# ## Define Model

# %% [markdown]
# ### Define sequntial model, add LSTM layer and compile the model

# %% [markdown]
# ### Summarize your model

# %% [markdown]
# ### Train the model

# %% [markdown]
# ## Make Predictions and Evaluate your model

# %% [markdown]
# ## Plot the results
